# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import utils

# %%
relative_path = "data/04_060__150_00_01_00C_230922_3D.tif"

img = utils.read_image(relative_path)
img.shape
# Out:
# (11759, 13006, 3)

# %%
image_small = cv2.resize(img, (500, 500))
plt.imshow(image_small)
